# %%
student = {
    'name': 'faizan',
    'age': 22,
    'courses': ['Math', 'CS']
}
print(student)
print(student['name'])
print(student['age'])
print(student['courses'])
# Out:
# {'name': 'faizan', 'age': 22, 'courses': ['Math', 'CS']}
# faizan
# 22
# ['Math', 'CS']

# %%
# keys() return all keys
print(student.keys())
# Out:
# dict_keys(['name', 'age', 'courses'])

# %%
# values() return all values
print(student.values())
# Out:
# dict_values(['faizan', 22, ['Math', 'CS']])

# %%
# .items() – Returns a view of all key-value pairs as tuples.
print(student.items())
# Out:
# dict_items([('name', 'faizan'), ('age', 22), ('courses', ['Math', 'CS'])])

# %%
student.update({"age": 23, "city": "New York"})
print(student)
# Out:
# {'name': 'faizan', 'age': 23, 'courses': ['Math', 'CS'], 'city': 'New York'}

# %%
student.setdefault("age", 25)
print(student)  # If 'age' wasn't present, it would be set to 25
# Out:
# {'name': 'faizan', 'age': 23, 'courses': ['Math', 'CS'], 'city': 'New York'}

# %%
student.clear()
print(student)  # Output: {}
# Out:
# {}
